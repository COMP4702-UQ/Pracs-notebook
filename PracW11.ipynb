# %% [markdown]
# <a href="https://colab.research.google.com/github/COMP4702-UQ/Pracs-notebook/blob/main/PracWk11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAC WEEK 11: SUPPORT VECTOR MACHINE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# TODO: Load preferred dataset (results are from 'diabetes' datasets)
df = pd.read_csv("...")

# TODO: Shuffle and split the data (random_state=42)
X_train, X_holdout, y_train, y_holdout = ...

# %% [markdown]
# ## Q1
# Train an SVM on the above data using a linear kernel and set C = 1. Show classification accuracy for both train and hold out sets, and confusion matrix

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix

# TODO: Train an SVM on the above data using a linear kernel and set parameter C = 1
svm = SVC()
# Out:
# SVC(C=1, kernel='linear')

# %% [markdown]
# # Q2

# %%
# TODO: Predict for train and holdout dataset
y_pred_train = ...
y_pred_holdout = ...

# TODO: Compute the accuracy score
train_accuracy = ...
holdout_accuracy = ...
print(f"Train accuracy: {np.round(train_accuracy*100, 2)}%")
print(f"Holdout accuracy: {np.around(holdout_accuracy*100, 2)}%")
# Out:
# Train accuracy: 78.03%
# Holdout accuracy: 74.46%

# %%
def plot_confusion_matrix(cm, class_names, title='Confusion Matrix'):
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# TODO: Compute the confusion matrices
train_confusion_matrix = ...
holdout_confusion_matrix = ...

# Define class names
class_names = np.unique(y_train)

# Plot both
plot_confusion_matrix(train_confusion_matrix, class_names, title='Train Confusion Matrix')
plot_confusion_matrix(holdout_confusion_matrix, class_names, title='Holdout Confusion Matrix')

# %% [markdown]
# ## Q3
# Vary the C parameter on a logarithmic scale, and show how it influences the training and testing error and the decision boundaries.

# %%
# TODO: Create a list of C values to try
C_values = ...
print(f"List of C values: {C_values}")

# TODO: Train and evaluate a model for each C value
train_accuracy_list = []
holdout_accuracy_list = []
for C in C_values:
  print(f"Fitting with C value: {C}")
  # TODO: train SVM

  # TODO: Predict target values

  # TODO: Calculate and record accuracy

# TODO: Plot the training and testing error as a function of C
# Out:
# List of C values: [1.e-02 1.e-01 1.e+00 1.e+01 1.e+02]
# Fitting with C value: 0.01
# Fitting with C value: 0.1
# Fitting with C value: 1.0
# Fitting with C value: 10.0
# Fitting with C value: 100.0

# %% [markdown]
# ## Q4:
# Experiment with different kernel functions, for a list  of 5 C values, and show how it influences the training and testing error

# %%
# TODO: Create a list of kernel functions to try
kernel_functions = ...

# TODO: Train and evaluate a model for each kernel function
train_accuracy_list = []
holdout_accuracy_list = []
for kernel in kernel_functions:
  print(f"Plotting with Kernel function: {kernel}")
  for C in C_values:
    # TODO: train SVM

    # TODO: Predict target values

    # TODO: Calculate and record accuracy
# Out:
# Plotting with Kernel function: linear
# Plotting with Kernel function: poly
# Plotting with Kernel function: rbf
# Plotting with Kernel function: sigmoid

# %%
# TODO: Plot the training error as a function of kernel and C

# %%
# TODO: Plot the testing error as a function of kernel and C
